# %% [markdown]
# # 🌐 Nhận Diện Ngôn Ngữ Tự Động — Language Detection
# > **Baseline NLP Pipeline** | AI Club | Cấp độ: Cơ bản
#
# ---
#
# ## 🎯 Mục tiêu
#
# Bạn sẽ hiểu và tự làm được **toàn bộ pipeline NLP** từ A đến Z:
#
# ```
# Raw Text → Tiền xử lý → Vector hóa → Huấn luyện → Đánh giá → Demo
# ```
#
# ## 📋 Nội dung
# 1. Setup môi trường & tải dataset
# 2. Khám phá dữ liệu (EDA)
# 3. Tiền xử lý văn bản
# 4. Vector hóa — TF-IDF với Character N-grams
# 5. Huấn luyện & so sánh mô hình
# 6. Đánh giá chi tiết
# 7. Phân tích lỗi
# 8. Demo thời gian thực
#
# ---
# 📦 **Dataset:** [Kaggle — Language Detection](https://www.kaggle.com/datasets/basilb2s/language-detection)

# %% [markdown]
# ---
# ## Bước 0 — Cài đặt thư viện
#
# > Chạy cell này nếu chưa cài. Trên **Google Colab** thì hầu hết đã có sẵn.

# %%
# Nếu chạy trên Colab / chưa có thư viện
# !pip install pandas numpy scikit-learn matplotlib seaborn

# %%
# ============================================================
# IMPORT TẤT CẢ THƯ VIỆN CẦN DÙNG
# ============================================================

import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# Scikit-learn — pipeline ML
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.naive_bayes import MultinomialNB, ComplementNB
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    ConfusionMatrixDisplay
)

import warnings
warnings.filterwarnings('ignore')

# Cài đặt hiển thị đẹp hơn
pd.set_option('display.max_colwidth', 100)
plt.rcParams['figure.dpi'] = 120
sns.set_style('whitegrid')

print("✅ Import thành công!")
# Out:
# ✅ Import thành công!

# %% [markdown]
# ---
# ## Bước 1 — Tải & Khám phá dữ liệu (EDA)
#
# ### 1.1 Tải dataset
#
# **Cách 1 — Kaggle CLI** (khuyến nghị):
# ```bash
# kaggle datasets download -d basilb2s/language-detection
# unzip language-detection.zip
# ```
#
# **Cách 2 — Tải thủ công:** vào link Kaggle ở trên, tải file `Language Detection.csv`

# %%
# Đọc dữ liệu
# Thay đường dẫn nếu file ở chỗ khác
df = pd.read_csv("Language Detection.csv")

print(f"📊 Kích thước dataset: {df.shape}")
print(f"📋 Các cột: {list(df.columns)}")
df.head(10)
# Out:
# 📊 Kích thước dataset: (10337, 2)
# 📋 Các cột: ['Text', 'Language']
#                                                                                                   Text  \
# 0                 Nature, in the broadest sense, is the natural, physical, material world or universe.
# 1              "Nature" can refer to the phenomena of the physical world, and also to life in general.
# 2                                    The study of nature is a large, if not the only, part of science.
# 3  Although humans are part of nature, human activity is often understood as a separate category fr...
# 4  [1] The word nature is borrowed from the Old French nature and is derived from the Latin word na...
# 5  [2] In ancient philosophy, natura is mostly used as the Latin translation of the Greek word phys...
# 6  [3][4] \nThe concept of nature as a whole, the physical universe, is one of several expansions o...
# ...

# %%
# Đổi tên cột cho tiện (nếu cần)
# Dataset gốc có 2 cột: 'Text' và 'Language'
df.columns = ['text', 'language']

# Kiểm tra giá trị null
print("🔍 Giá trị null:")
print(df.isnull().sum())

print(f"\n📌 Số ngôn ngữ trong dataset: {df['language'].nunique()}")
print(f"📌 Danh sách ngôn ngữ:")
print(sorted(df['language'].unique()))
# Out:
# 🔍 Giá trị null:
# text        0
# language    0
# dtype: int64
#
# 📌 Số ngôn ngữ trong dataset: 17
# 📌 Danh sách ngôn ngữ:
# ['Arabic', 'Danish', 'Dutch', 'English', 'French', 'German', 'Greek', 'Hindi', 'Italian', 'Kannada', 'Malayalam', 'Portugeese', 'Russian', 'Spanish', 'Sweedish', 'Tamil', 'Turkish']

# %% [markdown]
# ### 1.2 Sử dụng toàn bộ ngôn ngữ

# %%
# Dùng toàn bộ dataset, không lọc ngôn ngữ
df_filtered = df.copy()
df_filtered = df_filtered.reset_index(drop=True)

SELECTED_LANGUAGES = sorted(df_filtered['language'].unique().tolist())

print(f"📊 Dataset: {df_filtered.shape}")
print(f"📌 Tổng số ngôn ngữ: {len(SELECTED_LANGUAGES)}")
print("\n📈 Phân phối nhãn:")
print(df_filtered['language'].value_counts())
# Out:
# 📊 Dataset: (10337, 2)
# 📌 Tổng số ngôn ngữ: 17
#
# 📈 Phân phối nhãn:
# language
# English       1385
# French        1014
# Spanish        819
# Portugeese     739
# Italian        698
# Russian        692
# Sweedish       676
# Malayalam      594
# Dutch          546
# Arabic         536
# Turkish        474
# German         470
# Tamil          469
# Danish         428
# Kannada        369
# Greek          365
# Hindi           63
# Name: count, dtype: int64

# %% [markdown]
# ### 1.3 Trực quan hóa phân phối dữ liệu

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Biểu đồ 1: Số lượng mẫu mỗi ngôn ngữ
lang_counts = df_filtered['language'].value_counts()
colors = sns.color_palette('Set2', len(lang_counts))

axes[0].barh(lang_counts.index, lang_counts.values, color=colors)
axes[0].set_xlabel('Số lượng mẫu')
axes[0].set_title('Phân phối số mẫu theo ngôn ngữ', fontweight='bold')
for i, v in enumerate(lang_counts.values):
    axes[0].text(v + 5, i, str(v), va='center')

# Biểu đồ 2: Độ dài văn bản trung bình
df_filtered['text_length'] = df_filtered['text'].str.len()
df_filtered['word_count'] = df_filtered['text'].str.split().str.len()

avg_len = df_filtered.groupby('language')['text_length'].mean().sort_values(ascending=True)
axes[1].barh(avg_len.index, avg_len.values, color=colors)
axes[1].set_xlabel('Độ dài trung bình (ký tự)')
axes[1].set_title('Độ dài văn bản trung bình theo ngôn ngữ', fontweight='bold')

plt.tight_layout()
plt.show()

print("\n📊 Thống kê độ dài văn bản:")
print(df_filtered.groupby('language')['text_length'].describe().round(1))
# Out:
# 📊 Thống kê độ dài văn bản:
#              count    mean     std   min   25%    50%     75%      max
# language
# Arabic       536.0    99.2    81.2   1.0  37.0   80.0   141.0    581.0
# Danish       428.0    91.3    87.1   3.0  28.0   68.0   121.2    737.0
# Dutch        546.0    99.3    85.1   7.0  32.0   84.0   132.8    759.0
# English     1385.0   136.9    83.4   5.0  81.0  124.0   180.0    720.0
# French      1014.0   145.1   103.8   5.0  75.0  132.0   194.8   1168.0
# German       470.0    74.7    62.8   6.0  28.0   56.0   105.0    455.0
# Greek        365.0   106.3    97.1   5.0  28.0   87.0   157.0    733.0
# Hindi         63.0  1209.2  2833.6  15.0  45.5  189.0  1376.5  19088.0
# Italian      698.0   142.2   117.0   4.0  48.2  121.5   196.0   1007.0
# Kannada      369.0    87.7    79.1   5.0  29.0   58.0   118.0    443.0
# Malayalam    594.0    99.7    78.8   5.0  42.0   84.5   130.8    479.0
# Portugeese   739.0   139.3   119.5   5.0  55.0  122.0   192.0   1965.0
# ...

# %%
# Xem thử vài mẫu của mỗi ngôn ngữ
print("🔍 Mẫu dữ liệu từng ngôn ngữ:\n")
for lang in SELECTED_LANGUAGES:
    sample = df_filtered[df_filtered['language'] == lang]['text'].iloc[0]
    print(f"[{lang:10}] {sample[:120]}")
    print()
# Out:
# 🔍 Mẫu dữ liệu từng ngôn ngữ:
#
# [Arabic    ] نيتشر (بالإنجليزية: Nature)‏ قد تعني:    تعديل - تعديل مصدري - تعديل ويكي بيانات ويكيبيديا (تلفظ ‎[wi:ki:bi:dija:]‏ وتلح
#
# [Danish    ] Nature er et britisk multidisciplinært videnskabeligt tidsskrift, der blev udgivet første gang den 4. november 1869.
#
# [Dutch     ] Nature (Engels voor 'natuur') is een Brits vooral natuurwetenschappelijk tijdschrift.
#
# [English   ]  Nature, in the broadest sense, is the natural, physical, material world or universe.
#
# [French    ] Si vous disposez d'ouvrages ou d'articles de référence ou si vous connaissez des sites web de qualité traitant du thème
#
# [German    ] .Wir sind alle auf der Suche nach schnellen Wegen, um fließender Englisch zu sprechen.
#
# [Greek     ] Δεν υπάρχει αυτή τη στιγμή  λήμμα με αυτόν τον τίτλο.
#
# [Hindi     ] विकि-शब्दकोष (एक मुक्त शब्दकोष एवं समानांतर कोष)
#  विकिताबें (मुफ़्त क़िताबें और उपयोगी सामग्री)
#  विकिक्वोट (विभिन्न सु
#
# ...

# %% [markdown]
# ---
# ## Bước 2 — Tiền xử lý văn bản
#
# ### 💡 Lý thuyết nhanh
#
# Tiền xử lý cho bài toán **nhận diện ngôn ngữ** khác với các bài NLP thông thường:
#
# | Bài NLP thông thường | Nhận diện ngôn ngữ |
# |---|---|
# | Xóa stopwords | ❌ Không nên — stopwords chính là đặc trưng ngôn ngữ! |
# | Lowercase | ✅ Có thể |
# | Xóa số & ký hiệu đặc biệt | ⚠️ Cẩn thận — dấu accent (é, ñ, ü) là đặc trưng quan trọng |
#
# **Nguyên tắc:** Giữ lại những gì phân biệt ngôn ngữ, xóa nhiễu không cần thiết.

# %%
def preprocess_text(text):
    """
    Tiền xử lý văn bản cho bài toán nhận diện ngôn ngữ.
    
    Lưu ý: KHÔNG xóa accent, KHÔNG xóa stopwords
    vì chúng là đặc trưng phân biệt ngôn ngữ.
    """
    if not isinstance(text, str):
        return ""
    
    # Bước 1: Chuyển về chữ thường
    text = text.lower()
    
    # Bước 2: Xóa URL
    text = re.sub(r'http\S+|www\S+', '', text)
    
    # Bước 3: Xóa số (số không giúp phân biệt ngôn ngữ)
    text = re.sub(r'\d+', '', text)
    
    # Bước 4: Xóa ký tự đặc biệt thuần (giữ lại chữ cái Unicode)
    # \w giữ lại chữ cái, số, dấu gạch dưới
    # \s giữ lại khoảng trắng
    # Ký tự Unicode (như é, ü, ñ, ü, chữ Ả Rập, Hán tự...) được giữ lại
    text = re.sub(r'[^\w\s]', ' ', text)
    
    # Bước 5: Xóa khoảng trắng thừa
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text


# Kiểm tra hàm với vài ví dụ
test_cases = [
    "Hello! This is a TEST sentence. Visit https://example.com for more info.",
    "Bonjour, c'est une très belle journée!",
    "مرحبا، كيف حالك اليوم؟",
]

print("🧪 Kiểm tra hàm preprocess:")
for t in test_cases:
    print(f"  Input : {t}")
    print(f"  Output: {preprocess_text(t)}")
    print()
# Out:
# 🧪 Kiểm tra hàm preprocess:
#   Input : Hello! This is a TEST sentence. Visit https://example.com for more info.
#   Output: hello this is a test sentence visit for more info
#
#   Input : Bonjour, c'est une très belle journée!
#   Output: bonjour c est une très belle journée
#
#   Input : مرحبا، كيف حالك اليوم؟
#   Output: مرحبا كيف حالك اليوم

# %%
# Áp dụng tiền xử lý cho toàn bộ dataset
df_filtered['text_clean'] = df_filtered['text'].apply(preprocess_text)

# Kiểm tra sau tiền xử lý
print("📊 So sánh trước/sau tiền xử lý:")
print(df_filtered[['text', 'text_clean', 'language']].head(5).to_string())

# Loại bỏ các dòng có text rỗng sau khi làm sạch
before = len(df_filtered)
df_filtered = df_filtered[df_filtered['text_clean'].str.len() > 3]
after = len(df_filtered)
print(f"\n🗑️  Đã loại {before - after} dòng rỗng sau tiền xử lý")
# Out:
# 📊 So sánh trước/sau tiền xử lý:
#                                                                                                                                                                                                  text                                                                                                                                                                             text_clean language
# 0                                                                                                                Nature, in the broadest sense, is the natural, physical, material world or universe.                                                                                                        nature in the broadest sense is the natural physical material world or universe  English
# ...

# %% [markdown]
# ---
# ## Bước 3 — Vector hóa: Character N-grams
#
# ### 💡 Tại sao dùng Character N-grams?
#
# **Word-level (theo từ):**
# - `"bonjour"` → token `["bonjour"]`
# - Từ vựng mỗi ngôn ngữ hoàn toàn khác nhau → học được, nhưng không tổng quát
#
# **Character N-gram (theo cụm ký tự):**
# - `"bonjour"` với n=3 → `["bon", "onj", "njo", "jou", "our"]`
# - **Mỗi ngôn ngữ có "chữ ký" thống kê riêng** qua phân phối n-grams
# - Tiếng Pháp hay có `"ou"`, `"eau"`, `"tion"`
# - Tiếng Đức hay có `"sch"`, `"ung"`, `"ich"`
# - Robust hơn với từ mới / lỗi chính tả
#
# > 📌 **`analyzer='char_wb'`** = character ngrams nhưng không vượt ranh giới từ (word boundary)

# %%
# ============================================================
# CHIA DỮ LIỆU TRAIN / TEST
# ============================================================
X = df_filtered['text_clean']
y = df_filtered['language']

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,          # 20% dùng để test
    random_state=42,        # Fix seed để kết quả tái lập
    stratify=y              # Đảm bảo tỉ lệ ngôn ngữ đồng đều ở train/test
)

print(f"📊 Train set: {len(X_train)} mẫu")
print(f"📊 Test set : {len(X_test)} mẫu")
print(f"\n📈 Phân phối nhãn trong Train:")
print(y_train.value_counts())
# Out:
# 📊 Train set: 8260 mẫu
# 📊 Test set : 2065 mẫu
#
# 📈 Phân phối nhãn trong Train:
# language
# English       1107
# French         810
# Spanish        654
# Portugeese     591
# Italian        558
# Russian        552
# Sweedish       540
# Malayalam      475
# Dutch          437
# Arabic         427
# Turkish        379
# German         376
# Tamil          374
# Danish         342
# Kannada        295
# Greek          292
# Hindi           51
# Name: count, dtype: int64

# %%
# ============================================================
# MINH HỌA CHARACTER N-GRAMS
# ============================================================
# Để hiểu rõ hơn trước khi dùng TF-IDF

demo_vectorizer = CountVectorizer(
    analyzer='char_wb',
    ngram_range=(2, 3),   # lấy bigram và trigram
    max_features=10
)

demo_texts = ["bonjour monde", "hello world"]
demo_vectorizer.fit(demo_texts)

print("🔍 Ví dụ Character N-grams của 'bonjour monde' và 'hello world':")
print(f"Vocabulary: {list(demo_vectorizer.vocabulary_.keys())}")

print("\n💡 Giải thích: 'bonjour' → 'bo', 'on', 'nj', 'jo', 'ur' (bigrams)")
print("              'bonjour' → 'bon', 'onj', 'njo', 'jou', 'our' (trigrams)")
# Out:
# 🔍 Ví dụ Character N-grams của 'bonjour monde' và 'hello world':
# Vocabulary: [' b', 'on', 'nj', 'njo', 'mo', 'nd', 'mon', 'nde', 'o ', 'lo ']
#
# 💡 Giải thích: 'bonjour' → 'bo', 'on', 'nj', 'jo', 'ur' (bigrams)
#               'bonjour' → 'bon', 'onj', 'njo', 'jou', 'our' (trigrams)

# %%
# ============================================================
# TRỰC QUAN HÓA: Top N-grams đặc trưng mỗi ngôn ngữ
# ============================================================
print("📊 Top 10 Character Bigrams đặc trưng mỗi ngôn ngữ:\n")

n_langs = len(SELECTED_LANGUAGES)
n_cols = 4
n_rows = (n_langs + n_cols - 1) // n_cols
fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, n_rows * 4))
axes = axes.flatten()

for idx, lang in enumerate(SELECTED_LANGUAGES):
    lang_texts = df_filtered[df_filtered['language'] == lang]['text_clean'].tolist()
    
    # Tạo vectorizer cho ngôn ngữ này
    vec = CountVectorizer(analyzer='char_wb', ngram_range=(2, 2), max_features=15)
    X_lang = vec.fit_transform(lang_texts)
    
    # Tổng tần suất mỗi bigram
    freq = np.asarray(X_lang.sum(axis=0)).flatten()
    vocab = vec.get_feature_names_out()
    top_idx = freq.argsort()[-10:][::-1]
    
    top_ngrams = [vocab[i] for i in top_idx]
    top_freq = [freq[i] for i in top_idx]
    
    color = sns.color_palette('Set2', len(SELECTED_LANGUAGES))[idx]
    axes[idx].barh(top_ngrams[::-1], top_freq[::-1], color=color)
    axes[idx].set_title(f'{lang}', fontweight='bold', fontsize=12)
    axes[idx].set_xlabel('Tần suất')

# Ẩn các subplot thừa
for idx in range(len(SELECTED_LANGUAGES), len(axes)):
    axes[idx].set_visible(False)
plt.suptitle('Top 10 Character Bigrams đặc trưng mỗi ngôn ngữ', 
             fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

print("💡 Nhận xét: Mỗi ngôn ngữ có 'dấu vân tay' n-gram hoàn toàn khác nhau!")
# Out:
# 📊 Top 10 Character Bigrams đặc trưng mỗi ngôn ngữ:
# 💡 Nhận xét: Mỗi ngôn ngữ có 'dấu vân tay' n-gram hoàn toàn khác nhau!

# %% [markdown]
# ---
# ## Bước 4 — Huấn luyện & So sánh mô hình
#
# Ta sẽ dùng **`Pipeline`** của Scikit-learn — cách làm chuẩn trong thực tế:
#
# ```
# Pipeline = [Vectorizer] → [Model]
# ```
#
# Pipeline tự động:
# - Fit vectorizer trên train, transform test (không bị data leakage)
# - Gói gọn toàn bộ quy trình vào 1 object
# - Dễ deploy và tái sử dụng

# %%
# ============================================================
# ĐỊNH NGHĨA CÁC PIPELINE THÍ NGHIỆM
# ============================================================

# Vectorizer chung dùng cho tất cả thí nghiệm
TFIDF_CHAR = TfidfVectorizer(
    analyzer='char_wb',     # Character n-grams, không vượt ranh giới từ
    ngram_range=(2, 4),     # Dùng bigram đến 4-gram
    max_features=50000,     # Giới hạn số đặc trưng
    sublinear_tf=True,      # Dùng log(tf) thay vì tf (giảm ảnh hưởng của từ lặp nhiều)
    strip_accents=None,     # QUAN TRỌNG: Giữ lại dấu accent!
)

# Các mô hình cần so sánh
models = {
    "Naive Bayes (Multinomial)": Pipeline([
        ('tfidf', TfidfVectorizer(
            analyzer='char_wb', ngram_range=(2, 4),
            max_features=50000, sublinear_tf=True, strip_accents=None
        )),
        ('clf', MultinomialNB(alpha=0.1))
    ]),
    
    "Naive Bayes (Complement)": Pipeline([
        ('tfidf', TfidfVectorizer(
            analyzer='char_wb', ngram_range=(2, 4),
            max_features=50000, sublinear_tf=True, strip_accents=None
        )),
        ('clf', ComplementNB(alpha=0.1))  # Tốt hơn với imbalanced data
    ]),
    
    "Logistic Regression": Pipeline([
        ('tfidf', TfidfVectorizer(
            analyzer='char_wb', ngram_range=(2, 4),
            max_features=50000, sublinear_tf=True, strip_accents=None
        )),
        ('clf', LogisticRegression(
            max_iter=1000,
            C=5.0,           # Hệ số regularization (C lớn = ít regularize hơn)
            solver='lbfgs',
            multi_class='multinomial'
        ))
    ]),
}

print("✅ Đã định nghĩa", len(models), "pipeline thí nghiệm")
# Out:
# ✅ Đã định nghĩa 3 pipeline thí nghiệm

# %%
# ============================================================
# HUẤN LUYỆN VÀ ĐÁNH GIÁ TẤT CẢ MÔ HÌNH
# ============================================================
import time

results = {}

for name, pipeline in models.items():
    print(f"\n🚀 Đang huấn luyện: {name}")
    
    # Đo thời gian huấn luyện
    t0 = time.time()
    pipeline.fit(X_train, y_train)
    train_time = time.time() - t0
    
    # Dự đoán
    t1 = time.time()
    y_pred = pipeline.predict(X_test)
    infer_time = time.time() - t1
    
    # Tính Accuracy
    acc = accuracy_score(y_test, y_pred)
    
    results[name] = {
        'pipeline': pipeline,
        'y_pred': y_pred,
        'accuracy': acc,
        'train_time': train_time,
        'infer_time': infer_time,
    }
    
    print(f"   ✅ Accuracy: {acc:.4f} | Train: {train_time:.2f}s | Infer: {infer_time*1000:.1f}ms")

print("\n" + "="*60)
print("TỔNG KẾT:".center(60))
print("="*60)
summary = pd.DataFrame([
    {
        'Mô hình': name,
        'Accuracy': f"{r['accuracy']:.4f}",
        'Thời gian train (s)': f"{r['train_time']:.2f}",
        'Thời gian infer (ms)': f"{r['infer_time']*1000:.1f}",
    }
    for name, r in results.items()
])
print(summary.to_string(index=False))
# Out:
# 🚀 Đang huấn luyện: Naive Bayes (Multinomial)
#    ✅ Accuracy: 0.9913 | Train: 2.65s | Infer: 584.0ms
#
# 🚀 Đang huấn luyện: Naive Bayes (Complement)
#    ✅ Accuracy: 0.9903 | Train: 2.42s | Infer: 637.4ms
#
# 🚀 Đang huấn luyện: Logistic Regression
#    ✅ Accuracy: 0.9898 | Train: 15.39s | Infer: 711.8ms
#
# ...
#                          TỔNG KẾT:
# ...
#                   Mô hình Accuracy Thời gian train (s) Thời gian infer (ms)
# Naive Bayes (Multinomial)   0.9913                2.65                584.0
#  Naive Bayes (Complement)   0.9903                2.42                637.4
#       Logistic Regression   0.9898               15.39                711.8

# %% [markdown]
# ---
# ## Bước 5 — Đánh giá chi tiết
#
# ### 💡 Tại sao Accuracy chưa đủ?
#
# Với dataset **cân bằng** như bài này, Accuracy khá đáng tin. Nhưng trong thực tế:
# - Nếu 90% data là English → mô hình luôn đoán English vẫn đạt 90% Accuracy!
# - Cần xem thêm **Precision / Recall / F1** cho từng ngôn ngữ
#
# | Chỉ số | Ý nghĩa | Quan trọng khi... |
# |---|---|---|
# | **Precision** | Trong số những cái ta dự đoán là X, bao nhiêu % thực sự là X? | Sai thì tốn chi phí (spam lọc nhầm email quan trọng) |
# | **Recall** | Trong số những cái thực sự là X, ta phát hiện được bao nhiêu %? | Bỏ sót thì nguy hiểm (bỏ lọt virus, bỏ lọt bệnh) |
# | **F1-Score** | Trung bình điều hòa của Precision và Recall | Cần cân bằng cả hai |

# %%
# ============================================================
# CHỌN MÔ HÌNH TỐT NHẤT ĐỂ PHÂN TÍCH CHI TIẾT
# ============================================================
best_name = max(results, key=lambda k: results[k]['accuracy'])
best_result = results[best_name]
y_pred_best = best_result['y_pred']

print(f"🏆 Mô hình tốt nhất: {best_name}")
print(f"   Accuracy: {best_result['accuracy']:.4f}\n")

# Classification Report đầy đủ
print("📊 Classification Report (chi tiết từng ngôn ngữ):")
print("-" * 60)
print(classification_report(y_test, y_pred_best))
# Out:
# 🏆 Mô hình tốt nhất: Naive Bayes (Multinomial)
#    Accuracy: 0.9913
#
# 📊 Classification Report (chi tiết từng ngôn ngữ):
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#       Arabic       1.00      1.00      1.00       107
#       Danish       1.00      0.93      0.96        85
#        Dutch       0.99      0.98      0.99       109
#      English       0.98      1.00      0.99       277
#       French       1.00      1.00      1.00       203
#       German       1.00      0.99      0.99        94
#        Greek       1.00      1.00      1.00        73
#        Hindi       1.00      1.00      1.00        12
#      Italian       0.99      1.00      1.00       139
#      Kannada       1.00      1.00      1.00        74
#    Malayalam       1.00      1.00      1.00       118
#   Portugeese       0.99      0.99      0.99       148
#      Russian       1.00      1.00      1.00       138
# ...

# %%
# ============================================================
# CONFUSION MATRIX — Trực quan hóa
# ============================================================
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Lấy danh sách nhãn
labels = sorted(df_filtered['language'].unique())

# Plot 1: Confusion Matrix (số lượng)
cm = confusion_matrix(y_test, y_pred_best, labels=labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(ax=axes[0], colorbar=False, cmap='Blues')
axes[0].set_title(f'Confusion Matrix — {best_name}\n(số lượng)', fontweight='bold')
axes[0].tick_params(axis='x', rotation=45)

# Plot 2: Confusion Matrix (tỷ lệ %)
cm_norm = confusion_matrix(y_test, y_pred_best, labels=labels, normalize='true')
disp2 = ConfusionMatrixDisplay(confusion_matrix=cm_norm, display_labels=labels)
disp2.plot(ax=axes[1], colorbar=False, cmap='RdYlGn', values_format='.2f')
axes[1].set_title(f'Confusion Matrix — {best_name}\n(tỷ lệ % trên từng hàng)', fontweight='bold')
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

print("💡 Đọc Confusion Matrix:")
print("   - Đường chéo (xanh đậm) = dự đoán ĐÚNG")
print("   - Ô ngoài đường chéo = dự đoán SAI")
print("   - Ô [hàng A, cột B] = mẫu thực tế là A nhưng bị predict là B")
# Out:
# 💡 Đọc Confusion Matrix:
#    - Đường chéo (xanh đậm) = dự đoán ĐÚNG
#    - Ô ngoài đường chéo = dự đoán SAI
#    - Ô [hàng A, cột B] = mẫu thực tế là A nhưng bị predict là B

# %%
# ============================================================
# SO SÁNH F1-SCORE CÁC MÔ HÌNH THEO TỪNG NGÔN NGỮ
# ============================================================
from sklearn.metrics import f1_score

f1_data = {}
for name, r in results.items():
    f1_per_class = f1_score(y_test, r['y_pred'], labels=labels, average=None)
    f1_data[name] = f1_per_class

f1_df = pd.DataFrame(f1_data, index=labels)

plt.figure(figsize=(12, 5))
f1_df.plot(kind='bar', figsize=(12, 5), colormap='Set2')
plt.title('F1-Score theo từng ngôn ngữ', fontweight='bold', fontsize=13)
plt.xlabel('Ngôn ngữ')
plt.ylabel('F1-Score')
plt.xticks(rotation=0)
plt.ylim(0, 1.05)
plt.legend(loc='lower right')
plt.axhline(y=0.95, color='red', linestyle='--', alpha=0.5, label='Ngưỡng 0.95')
plt.tight_layout()
plt.show()

print("\n📊 Bảng F1-Score chi tiết:")
print(f1_df.round(4).to_string())
# Out:
# 📊 Bảng F1-Score chi tiết:
#             Naive Bayes (Multinomial)  Naive Bayes (Complement)  Logistic Regression
# Arabic                         1.0000                    1.0000               1.0000
# Danish                         0.9634                    0.9512               0.9701
# Dutch                          0.9862                    0.9815               0.9815
# English                        0.9875                    0.9892               0.9892
# French                         0.9951                    0.9901               0.9926
# German                         0.9947                    0.9947               0.9895
# Greek                          1.0000                    1.0000               1.0000
# Hindi                          1.0000                    1.0000               1.0000
# Italian                        0.9964                    0.9929               0.9855
# Kannada                        1.0000                    1.0000               1.0000
# ...

# %% [markdown]
# ---
# ## Bước 6 — Phân tích lỗi (Error Analysis)
#
# Đây là bước **quan trọng nhất** mà nhiều người bỏ qua. Khi mô hình sai, tại sao?
# - Do text quá ngắn?
# - Do ngôn ngữ có nhiều từ mượn (loanwords)?
# - Do tiền xử lý làm mất thông tin?
#
# Hiểu lỗi → biết cách cải thiện.

# %%
# ============================================================
# TẠO DATAFRAME PHÂN TÍCH LỖI
# ============================================================
best_pipeline = best_result['pipeline']

# Tạo DataFrame với kết quả dự đoán
test_df = pd.DataFrame({
    'text_original': df_filtered.loc[X_test.index, 'text'].values,
    'text_clean': X_test.values,
    'true_label': y_test.values,
    'pred_label': y_pred_best,
})

test_df['is_correct'] = test_df['true_label'] == test_df['pred_label']
test_df['text_length'] = test_df['text_clean'].str.len()

# Tỉ lệ đúng/sai
print(f"✅ Dự đoán đúng: {test_df['is_correct'].sum()} / {len(test_df)} ({test_df['is_correct'].mean():.2%})")
print(f"❌ Dự đoán sai : {(~test_df['is_correct']).sum()} mẫu")
# Out:
# ✅ Dự đoán đúng: 2047 / 2065 (99.13%)
# ❌ Dự đoán sai : 18 mẫu

# %%
# Xem các mẫu bị dự đoán SAI
errors = test_df[~test_df['is_correct']].copy()
errors = errors.sort_values('text_length')

print(f"\n🔍 CÁC MẪU BỊ DỰ ĐOÁN SAI ({len(errors)} mẫu):\n")
for _, row in errors.head(15).iterrows():
    print(f"  True: [{row['true_label']:10}] | Pred: [{row['pred_label']:10}] | Độ dài: {row['text_length']}")
    print(f"  Text: {row['text_original'][:100]}")
    print()
# Out:
# 🔍 CÁC MẪU BỊ DỰ ĐOÁN SAI (18 mẫu):
#
#   True: [Spanish   ] | Pred: [Sweedish  ] | Độ dài: 5
#   Text: venga.
#
#   True: [Danish    ] | Pred: [Sweedish  ] | Độ dài: 6
#   Text: Åh gud.
#
#   True: [Portugeese] | Pred: [Spanish   ] | Độ dài: 6
#   Text: cuidar.
#
#   True: [Danish    ] | Pred: [Sweedish  ] | Độ dài: 6
#   Text: Åh gud.
#
#   True: [Turkish   ] | Pred: [English   ] | Độ dài: 8
#   Text: tereddüt.
#
#   True: [English   ] | Pred: [French    ] | Độ dài: 10
#   Text: permission.
#
#   True: [Dutch     ] | Pred: [English   ] | Độ dài: 10
#   Text: suggesties.
#
#   True: [French    ] | Pred: [English   ] | Độ dài: 11
#   Text: suggestions.
#
#   True: [Danish    ] | Pred: [Sweedish  ] | Độ dài: 13
#   Text: holde kontakt.
#
#   True: [Danish    ] | Pred: [Sweedish  ] | Độ dài: 14
#   Text: rocker du rock?
#
#   True: [German    ] | Pred: [Dutch     ] | Độ dài: 15
#   Text: Menschen danken.
#
#   True: [Spanish   ] | Pred: [English   ] | Độ dài: 16
# ...

# %%
# ============================================================
# PHÂN TÍCH: Độ dài văn bản ảnh hưởng đến độ chính xác?
# ============================================================
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Phân phối độ dài: đúng vs sai
axes[0].hist(
    test_df[test_df['is_correct']]['text_length'], 
    bins=40, alpha=0.6, label='Đúng', color='green'
)
axes[0].hist(
    test_df[~test_df['is_correct']]['text_length'], 
    bins=40, alpha=0.6, label='Sai', color='red'
)
axes[0].set_xlabel('Độ dài văn bản (ký tự)')
axes[0].set_ylabel('Số lượng mẫu')
axes[0].set_title('Phân phối độ dài: Đúng vs Sai', fontweight='bold')
axes[0].legend()
axes[0].set_xlim(0, 500)

# Tỉ lệ đúng theo bins độ dài
test_df['length_bin'] = pd.cut(test_df['text_length'], 
                                bins=[0, 30, 60, 100, 200, 500, 10000],
                                labels=['0-30', '30-60', '60-100', '100-200', '200-500', '500+'])
acc_by_length = test_df.groupby('length_bin', observed=True)['is_correct'].mean()

axes[1].bar(acc_by_length.index, acc_by_length.values, 
            color=sns.color_palette('RdYlGn', len(acc_by_length)))
axes[1].set_xlabel('Độ dài văn bản (ký tự)')
axes[1].set_ylabel('Accuracy')
axes[1].set_title('Accuracy theo độ dài văn bản', fontweight='bold')
axes[1].set_ylim(0, 1.05)
for i, v in enumerate(acc_by_length.values):
    axes[1].text(i, v + 0.01, f'{v:.2f}', ha='center', fontsize=11)

plt.tight_layout()
plt.show()

print("\n💡 Nhận xét: Văn bản ngắn thường khó nhận diện hơn")
print("   vì ít n-gram đặc trưng → mô hình thiếu thông tin để quyết định")
# Out:
# 💡 Nhận xét: Văn bản ngắn thường khó nhận diện hơn
#    vì ít n-gram đặc trưng → mô hình thiếu thông tin để quyết định

# %%
# ============================================================
# PHÂN TÍCH: Cặp ngôn ngữ nào hay bị nhầm nhau nhất?
# ============================================================
print("🔍 Top 10 cặp (true → predicted) bị nhầm nhiều nhất:\n")

error_pairs = errors.groupby(['true_label', 'pred_label']).size().reset_index(name='count')
error_pairs = error_pairs.sort_values('count', ascending=False)
print(error_pairs.head(10).to_string(index=False))

print("\n💡 Gợi ý thảo luận:")
print("   - Những cặp nào bị nhầm? Có logic không?")
print("   - Ví dụ: French ↔ Spanish (cùng Romance) dễ nhầm hơn French ↔ Chinese")
# Out:
# 🔍 Top 10 cặp (true → predicted) bị nhầm nhiều nhất:
#
# true_label pred_label  count
#     Danish   Sweedish      6
#      Dutch    English      2
#    English     French      1
#     French    English      1
#     German      Dutch      1
# Portugeese    Italian      1
# Portugeese    Spanish      1
#    Spanish    English      1
#    Spanish Portugeese      1
#    Spanish   Sweedish      1
#
# 💡 Gợi ý thảo luận:
#    - Những cặp nào bị nhầm? Có logic không?
#    - Ví dụ: French ↔ Spanish (cùng Romance) dễ nhầm hơn French ↔ Chinese

# %% [markdown]
# ---
# ## Bước 7 — Thí nghiệm bổ sung: Word-level vs Char-level
#
# So sánh để hiểu **tại sao** char n-grams tốt hơn cho bài toán này.

# %%
# ============================================================
# SO SÁNH: WORD-LEVEL vs CHAR-LEVEL TF-IDF
# ============================================================
print("🧪 Thí nghiệm: So sánh Word-level vs Char-level\n")

experiments = {
    "Word unigrams": TfidfVectorizer(analyzer='word', ngram_range=(1,1), max_features=50000),
    "Word bigrams": TfidfVectorizer(analyzer='word', ngram_range=(1,2), max_features=50000),
    "Char (2-3) gram": TfidfVectorizer(analyzer='char_wb', ngram_range=(2,3), max_features=50000, strip_accents=None),
    "Char (2-4) gram": TfidfVectorizer(analyzer='char_wb', ngram_range=(2,4), max_features=50000, strip_accents=None),
    "Char (3-5) gram": TfidfVectorizer(analyzer='char_wb', ngram_range=(3,5), max_features=50000, strip_accents=None),
}

exp_results = []

for exp_name, vectorizer in experiments.items():
    pipe = Pipeline([
        ('tfidf', vectorizer),
        ('clf', LogisticRegression(max_iter=1000, C=5.0, solver='lbfgs', multi_class='multinomial'))
    ])
    pipe.fit(X_train, y_train)
    acc = accuracy_score(y_test, pipe.predict(X_test))
    vocab_size = len(vectorizer.vocabulary_)
    print(f"  {exp_name:20} | Accuracy: {acc:.4f} | Vocab size: {vocab_size:,}")
    exp_results.append({'Vectorizer': exp_name, 'Accuracy': acc, 'Vocab Size': vocab_size})

exp_df = pd.DataFrame(exp_results)

# Vẽ biểu đồ so sánh
fig, axes = plt.subplots(1, 2, figsize=(13, 4))
colors = ['#e74c3c' if 'Word' in r else '#2ecc71' for r in exp_df['Vectorizer']]

axes[0].barh(exp_df['Vectorizer'], exp_df['Accuracy'], color=colors)
axes[0].set_xlabel('Accuracy')
axes[0].set_title('So sánh Accuracy', fontweight='bold')
axes[0].set_xlim(0.85, 1.01)
for i, v in enumerate(exp_df['Accuracy']):
    axes[0].text(v + 0.001, i, f'{v:.4f}', va='center')

axes[1].barh(exp_df['Vectorizer'], exp_df['Vocab Size'], color=colors)
axes[1].set_xlabel('Vocab Size')
axes[1].set_title('Kích thước Vocabulary', fontweight='bold')

from matplotlib.patches import Patch
legend_elements = [Patch(facecolor='#e74c3c', label='Word-level'), 
                   Patch(facecolor='#2ecc71', label='Char-level')]
axes[0].legend(handles=legend_elements, loc='lower right')

plt.tight_layout()
plt.show()
# Out:
# 🧪 Thí nghiệm: So sánh Word-level vs Char-level
#
#   Word unigrams        | Accuracy: 0.9632 | Vocab size: 34,373
#   Word bigrams         | Accuracy: 0.9642 | Vocab size: 50,000
#   Char (2-3) gram      | Accuracy: 0.9874 | Vocab size: 30,864
#   Char (2-4) gram      | Accuracy: 0.9893 | Vocab size: 50,000
#   Char (3-5) gram      | Accuracy: 0.9874 | Vocab size: 50,000

# %% [markdown]
# ---
# ## Bước 8 — Demo thời gian thực
#
# Phần thú vị nhất! Test thử mô hình với câu bất kỳ.

# %%
# ============================================================
# HÀM DEMO: Nhận diện ngôn ngữ + hiển thị confidence
# ============================================================

def detect_language(text, pipeline, top_k=3):
    """
    Nhận diện ngôn ngữ và trả về top-k ngôn ngữ có xác suất cao nhất.
    
    Args:
        text     : chuỗi văn bản đầu vào
        pipeline : sklearn Pipeline đã huấn luyện
        top_k    : số ngôn ngữ hiển thị
    """
    # Tiền xử lý
    text_clean = preprocess_text(text)
    
    # Lấy xác suất từng ngôn ngữ
    proba = pipeline.predict_proba([text_clean])[0]
    classes = pipeline.classes_
    
    # Sắp xếp theo xác suất giảm dần
    top_indices = proba.argsort()[-top_k:][::-1]
    
    print(f"\n📝 Input  : '{text}'")
    print(f"🔍 Cleaned: '{text_clean}'")
    print(f"\n🏆 Kết quả (Top {top_k}):")
    print(f"{'Rank':<6} {'Ngôn ngữ':<15} {'Xác suất':<12} {'Bar'}")
    print("-" * 55)
    for rank, idx in enumerate(top_indices, 1):
        lang = classes[idx]
        prob = proba[idx]
        bar = '█' * int(prob * 30)
        marker = " ← 🏆" if rank == 1 else ""
        print(f"#{rank:<5} {lang:<15} {prob:.4f} ({prob:.1%})  {bar}{marker}")
    print()


# Lấy pipeline tốt nhất
best_pipeline = results[best_name]['pipeline']

print("=" * 60)
print("DEMO NHẬN DIỆN NGÔN NGỮ".center(60))
print("=" * 60)
# Out:
# ...
#                   DEMO NHẬN DIỆN NGÔN NGỮ
# ...

# %%
# ============================================================
# THỬ CÁC CÂU VÍ DỤ
# ============================================================

test_sentences = [
    # Câu rõ ràng
    "The weather is beautiful today and I love machine learning.",
    "Le temps est magnifique aujourd'hui, j'adore l'intelligence artificielle.",
    "مرحبا بكم في عالم الذكاء الاصطناعي",
    "人工智能是未来的技术趋势",
    "인공지능은 미래의 핵심 기술입니다",
    "कृत्रिम बुद्धिमत्ता भविष्य की तकनीक है",
    
    # Câu khó / ngắn
    "Hello!",
    "OK",
    "AI",
    
    # Câu hỗn hợp (code-switching)
    "This is a test sentence avec quelques mots en français",
]

for sentence in test_sentences:
    detect_language(sentence, best_pipeline, top_k=3)
    print("-" * 60)
# Out:
# 📝 Input  : 'The weather is beautiful today and I love machine learning.'
# 🔍 Cleaned: 'the weather is beautiful today and i love machine learning'
#
# 🏆 Kết quả (Top 3):
# Rank   Ngôn ngữ        Xác suất     Bar
# -------------------------------------------------------
# #1     English         1.0000 (100.0%)  █████████████████████████████ ← 🏆
# #2     Italian         0.0000 (0.0%)
# #3     French          0.0000 (0.0%)
#
# ------------------------------------------------------------
#
# 📝 Input  : 'Le temps est magnifique aujourd'hui, j'adore l'intelligence artificielle.'
# 🔍 Cleaned: 'le temps est magnifique aujourd hui j adore l intelligence artificielle'
#
# 🏆 Kết quả (Top 3):
# Rank   Ngôn ngữ        Xác suất     Bar
# -------------------------------------------------------
# #1     French          1.0000 (100.0%)  █████████████████████████████ ← 🏆
# #2     Italian         0.0000 (0.0%)
# #3     English         0.0000 (0.0%)
#
# ...

# %%
# ============================================================
# 🎮 INTERACTIVE: Nhập câu tùy ý
# ============================================================

print("🎮 Nhập câu bất kỳ để nhận diện ngôn ngữ:")
print("   (nhập 'quit' để thoát)\n")

while True:
    user_input = input(">>> Nhập văn bản: ")
    if user_input.lower() in ['quit', 'q', 'exit', '']:
        print("👋 Thoát demo.")
        break
    detect_language(user_input, best_pipeline, top_k=3)
# Out:
# 🎮 Nhập câu bất kỳ để nhận diện ngôn ngữ:
#    (nhập 'quit' để thoát)
# >>> Nhập văn bản:  My name is Huy
# 📝 Input  : 'My name is Huy'
# 🔍 Cleaned: 'my name is huy'
#
# 🏆 Kết quả (Top 3):
# Rank   Ngôn ngữ        Xác suất     Bar
# -------------------------------------------------------
# #1     English         0.9828 (98.3%)  █████████████████████████████ ← 🏆
# #2     Spanish         0.0060 (0.6%)
# #3     Dutch           0.0036 (0.4%)
# >>> Nhập văn bản:  La vida es mejor cuando aprendes algo nuevo cada día
# 📝 Input  : 'La vida es mejor cuando aprendes algo nuevo cada día'
# 🔍 Cleaned: 'la vida es mejor cuando aprendes algo nuevo cada día'
#
# 🏆 Kết quả (Top 3):
# Rank   Ngôn ngữ        Xác suất     Bar
# -------------------------------------------------------
# #1     Spanish         1.0000 (100.0%)  █████████████████████████████ ← 🏆
# #2     Portugeese      0.0000 (0.0%)
# #3     Italian         0.0000 (0.0%)

# %% [markdown]
# ---
# ## Bước 9 — Tổng kết & Câu hỏi thảo luận
#
# ### ✅ Những gì đã học trong buổi này
#
# | Pipeline Stage | Kỹ thuật sử dụng |
# |---|---|
# | **Load & EDA** | pandas, matplotlib, seaborn |
# | **Preprocessing** | lowercase, regex, strip noise |
# | **Vectorization** | TF-IDF, Character N-grams |
# | **Modeling** | Naive Bayes, Logistic Regression, Pipeline |
# | **Evaluation** | Accuracy, Precision, Recall, F1, Confusion Matrix |
# | **Error Analysis** | Phân tích độ dài, cặp nhầm lẫn |
#
# ---
#
# ### 💬 Câu hỏi thảo luận
#
# 1. **Tại sao Character N-grams tốt hơn Word-level cho bài này?**
#    - Gợi ý: Ngôn ngữ nào có chữ viết hoàn toàn khác nhau?
#
# 2. **Mô hình gặp khó khăn nhất với câu ngắn. Tại sao? Giải pháp?**
#    - Gợi ý: Ngưỡng độ dài tối thiểu? Ensemble?
#
# 3. **Accuracy = 99% có nghĩa là mô hình "hoàn hảo" chưa?**
#    - Gợi ý: Nếu deploy cho app thực tế, 1% lỗi tương đương bao nhiêu user?
#
# 4. **Thêm tiếng Việt vào thì phải làm gì?**
#    - Gợi ý: Thu thập data, rebalance, retrain
#
# ---
#
# ### 🚀 Mở rộng
#
# - [ ] **Thêm tiếng Việt** vào danh sách ngôn ngữ
# - [ ] **Export model** với `joblib` để dùng lại
# - [ ] **Wrap thành API** đơn giản bằng Flask/FastAPI
# - [ ] **Thử với văn bản cực ngắn** (1-2 từ) và phân tích
# - [ ] **Thay Logistic Regression bằng LinearSVC** và so sánh tốc độ

# %%
# ============================================================
# BONUS: Lưu model để dùng lại
# ============================================================
import joblib

# Lưu pipeline tốt nhất
joblib.dump(best_pipeline, 'language_detector.pkl')
print(f"✅ Đã lưu model: 'language_detector.pkl'")

# Load lại và test
loaded_model = joblib.load('language_detector.pkl')
test_text = "Bonjour, je suis ravi de vous rencontrer."
prediction = loaded_model.predict([preprocess_text(test_text)])[0]
print(f"\n🧪 Test load model:")
print(f"   Input: '{test_text}'")
print(f"   Predict: {prediction}")
